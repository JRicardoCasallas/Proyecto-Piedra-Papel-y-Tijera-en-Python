# %%
#Desarrollar un algoritmo que nos muestre la probabildad de empate.
import random

reglas = {
    "piedra": ["tijeras", "rata"],
    "papel": ["piedra", "spoke"],
    "tijeras": ["papel", "rata"],
    "rata": ["papel", "spoke"],
    "spoke": ["tijeras", "piedra"]
}

n_partidas = int(input("Ingrese el número de partidas a jugar: "))
partida = 1
resultados = []
jugador_1 = 0
jugador_2 = 0

while partida <= n_partidas:
    eleccion_jugador_1 = random.choice(list(reglas.keys()))
    eleccion_jugador_2 = random.choice(list(reglas.keys()))
    resultados.append((eleccion_jugador_1, eleccion_jugador_2))
    
    if eleccion_jugador_1 != eleccion_jugador_2:
        if eleccion_jugador_2 in reglas[eleccion_jugador_1]:
            jugador_1 += 1
        else:
            jugador_2 += 1
            
    partida += 1
    
    # Mostrar resultados de la partida
    print("\n las juagadas son:, resultados")
    print("\n -----Resumen del juego----------")
    print("Puntos del jugador 1:", jugador_1)
    print("Puntos del jugador 2:", jugador_2)
    
    
    #Operador ternario para determinar el ganador
    print("Empate" if jugador_2 == jugador_1 else "El jugador 1 gana" if jugador_1 > jugador_2 else "El jugador 2 gana")

   #calcular el porcentaje de partidas que se empataron
prob_empate = ((n_partidas - jugador_1 - jugador_2)/n_partidas * 100)
print('El porcentaje de partidas que terminaron en empate es:', prob_empate)
# Out:
#  las juagadas son:, resultados
#
#  -----Resumen del juego----------
# Puntos del jugador 1: 1
# Puntos del jugador 2: 0
# El jugador 1 gana
#
#  las juagadas son:, resultados
#
#  -----Resumen del juego----------
# Puntos del jugador 1: 2
# Puntos del jugador 2: 0
# El jugador 1 gana
#
#  las juagadas son:, resultados
#
#  -----Resumen del juego----------
# Puntos del jugador 1: 3
# Puntos del jugador 2: 0
# El jugador 1 gana
#
#  las juagadas son:, resultados
#
#  -----Resumen del juego----------
# Puntos del jugador 1: 4
# Puntos del jugador 2: 0
# El jugador 1 gana
#
#  las juagadas son:, resultados
#
#  -----Resumen del juego----------
# Puntos del jugador 1: 4
# Puntos del jugador 2: 1
# El jugador 1 gana
#
#  las juagadas son:, resultados
#
#  -----Resumen del juego----------
# Puntos del jugador 1: 5
# Puntos del jugador 2: 1
# El jugador 1 gana
#
#  las juagadas son:, resultados
#
#  -----Resumen del juego----------
# Puntos del jugador 1: 5
# Puntos del jugador 2: 2
# El jugador 1 gana
#
#  las juagadas son:, resultados
#
#  -----Resumen del juego----------
# Puntos del jugador 1: 5
# Puntos del jugador 2: 3
# El jugador 1 gana
#
#  las juagadas son:, resultados
#
#  -----Resumen del juego----------
# Puntos del jugador 1: 5
# Puntos del jugador 2: 3
# El jugador 1 gana
#
#  las juagadas son:, resultados
#
#  -----Resumen del juego----------
# Puntos del jugador 1: 5
# Puntos del jugador 2: 3
# El jugador 1 gana
# El porcentaje de partidas que terminaron en empate es: 20.0

# %% [markdown]
# # 1.random.choice(...):
#
# Esta función pertenece al módulo random de Python y se utiliza para seleccionar un elemento aleatorio de una secuencia (como una lista o una tupla).
#
# # list(reglas.keys()):
#
# reglas es un diccionario (o dict) en Python. La función keys() devuelve una vista de las claves del diccionario. Al envolverlo con list(...), se convierte en una lista de las claves.
#
# # Asignación a eleccion_jugador_1 y eleccion_jugador_2:
#
# En la primera línea, se selecciona aleatoriamente una clave del diccionario reglas y se asigna a la variable eleccion_jugador_1.
# En la segunda línea, se hace lo mismo para eleccion_jugador_2.
#
#
# # Asignación a eleccion_jugador_1 y eleccion_jugador_2:
#
# En la primera línea, se selecciona aleatoriamente una clave del diccionario reglas y se asigna a la variable eleccion_jugador_1.
# En la segunda línea, se hace lo mismo para eleccion_jugador_2.
